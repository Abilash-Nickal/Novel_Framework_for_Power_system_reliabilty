# %%
import random
availableGen=15
H=0

# %%
# Load levels for different time blocks
LoadLevels = [5, 10, 25, 20]

# 2. Select Current Load Level
load_rand = random.random()
if load_rand < 0.25:
    currentLoad = LoadLevels[0]
elif load_rand < 0.5:
    currentLoad = LoadLevels[1]
elif load_rand < 0.75:
    currentLoad = LoadLevels[2]
else:
    currentLoad = LoadLevels[3]
print(currentLoad)
# Out:
# 5

# %%
for _ in range(100000):
# H: Loss of Load Events Counter
# 3. Check for Loss of Load
    if currentLoad > availableGen:
         H += 1
         lol_event = True  # Flag the event
print(H)
# Out:
# 0
